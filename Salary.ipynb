# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
datas = pd.read_csv("salary data.csv")
print(datas.head())
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
print("Shape:", datas.shape)
print("\nColumns:")
print(datas.columns)

print("\nInfo:")
print(datas.info())

print("\nStatistical Summary:")
print(datas.describe())
# Out:
# Shape: (375, 6)
#
# Columns:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB
# None
#
# Statistical Summary:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# ...

# %%
print("\nMissing Values:")
print(datas.isnull().sum())

plt.figure(figsize=(8,4))
sns.heatmap(datas.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()
# Out:
# Missing Values:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
df = datas.fillna(df.mean(numeric_only=True))

for col in df.select_dtypes(include="object"):
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
num_cols = df.select_dtypes(include=np.number).columns  



for col in num_cols:
    plt.figure(figsize=(5,3))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
cat_cols = df.select_dtypes(include="object").columns 

for col in cat_cols:
    plt.figure(figsize=(6,3))
    sns.countplot(x=df[col])
    plt.xticks(rotation=45)
    plt.title(f"Count Plot of {col}")
    plt.show()

# %%
sns.pairplot(datas) 
plt.show()

# %%
plt.figure(figsize=(10,6))       
corr = datas.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
for col in num_cols:             
    plt.figure(figsize=(5,3))
    sns.boxplot(x=df[col])
    plt.title(f"Outliers in {col}")
    plt.show

# %%
datas.to_csv("salary data.csv", index=False)
print("Cleaned dataset saved!")
# Out:
# Cleaned dataset saved!

# %%
print("Duplicate rows:", datas.duplicated().sum())
df = datas.drop_duplicates()
# Out:
# Duplicate rows: 50

# %%
print("Duplicate colums:", df.duplicated().sum())
df = df.drop_duplicates()
# Out:
# Duplicate colums: 0

# %%
for col in df.columns:     
    print(f"{col} --> {df[col].nunique()} unique values")
# Out:
# Age --> 31 unique values
# Gender --> 2 unique values
# Education Level --> 3 unique values
# Job Title --> 174 unique values
# Years of Experience --> 28 unique values
# Salary --> 36 unique values

# %%
print(datas["Age"].value_counts())   

sns.countplot(x=df["Age"])
plt.title("Age Valuvation")
plt.show()
# Out:
# Age
# 33.0    24
# 29.0    23
# 35.0    22
# 44.0    21
# 31.0    21
# 36.0    20
# 45.0    17
# 34.0    17
# 47.0    15
# 30.0    15
# 38.0    15
# 40.0    13
# 28.0    13
# 32.0    12
# 39.0    12
# 43.0    12
# 41.0    12
# 37.0    12
# 42.0    11
# 46.0    10
# 27.0     9
# 48.0     9
# 50.0     8
# 49.0     8
# 26.0     7
# 51.0     5
# 25.0     4
# 52.0     3
# 24.0     1
# 23.0     1
# 53.0     1
# Name: count, dtype: int64

# %%
print(df["Gender"].value_counts())   

sns.countplot(x=datas["Gender"])
plt.title("Gender Valuvation")
plt.show()
# Out:
# Gender
# Male      170
# Female    154
# Name: count, dtype: int64

# %%
print(df["Education Level"].value_counts())  
sns.countplot(x=df["Education Level"])
plt.title("Education Level Valuvation")
plt.show()
# Out:
# Education Level
# Bachelor's    191
# Master's       91
# PhD            42
# Name: count, dtype: int64

# %%
print(datas["Job Title"].value_counts())   

sns.countplot(x=datas["Job Title"])
plt.title("Job Title Valuation")
plt.show()
# Out:
# Job Title
# Director of Marketing             12
# Director of Operations            11
# Senior Business Analyst           10
# Senior Marketing Manager           9
# Senior Marketing Analyst           9
#                                   ..
# Junior Social Media Specialist     1
# Junior Operations Coordinator      1
# Senior HR Specialist               1
# Director of HR                     1
# Junior Financial Advisor           1
# Name: count, Length: 174, dtype: int64

# %%
print(datas["Years of Experience"].value_counts())    

sns.countplot(x=datas["Years of Experience"])
plt.title("Years of Experience Valuation")
plt.show()
# Out:
# Years of Experience
# 2.0     31
# 3.0     30
# 8.0     25
# 9.0     22
# 4.0     20
# 16.0    18
# 10.0    18
# 7.0     18
# 5.0     17
# 15.0    16
# 19.0    15
# 12.0    15
# 21.0    13
# 14.0    13
# 18.0    13
# 20.0    13
# 1.5     12
# 6.0     12
# 13.0    11
# 11.0    10
# 22.0     9
# 1.0      7
# 17.0     5
# 0.0      3
# 25.0     3
# 23.0     2
# 24.0     1
# 0.5      1
# Name: count, dtype: int64

# %%
print(datas["Salary"].value_counts())  
sns.countplot(x=datas["Salary"])
plt.title("Salary Valuation")
plt.show()
# Out:
# Salary
# 40000.0     31
# 50000.0     22
# 95000.0     22
# 120000.0    20
# 180000.0    20
# 45000.0     18
# 150000.0    18
# 90000.0     18
# 160000.0    17
# 60000.0     17
# 110000.0    17
# 170000.0    16
# 130000.0    14
# 100000.0    14
# 140000.0    14
# 35000.0     13
# 80000.0     12
# 55000.0     10
# 85000.0     10
# 65000.0      9
# 70000.0      9
# 105000.0     6
# 75000.0      4
# 190000.0     4
# 115000.0     3
# 200000.0     2
# 135000.0     2
# 250000.0     2
# 175000.0     2
# 125000.0     1
# 30000.0      1
# 220000.0     1
# 185000.0     1
# 145000.0     1
# 155000.0     1
# 350.0        1
# Name: count, dtype: int64

# %%
print("Skewness:")
print(datas.skew(numeric_only=True))
for col in num_cols:
    if abs(datas[col].skew()) > 3:
        df[col] = np.log1p(df[col])
# Out:
# Skewness:
# Age                    0.197522
# Years of Experience    0.361220
# Salary                 0.400578
# dtype: float64

# %%
datas.groupby("Age")["Age"].mean()        
datas.groupby("Age")["Age"].mean().plot(kind="bar")         
plt.title("Age of salary data")
plt.show()

# %%
datas.groupby("Salary")["Salary"].mean()        
datas.groupby("Salary")["Salary"].mean().plot(kind="bar")         
plt.title("salary salary file")
# Out:
# Text(0.5, 1.0, 'salary salary file')

# %%
corr_matrix = datas.corr(numeric_only=True).abs()

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

high_corr = [column for column in upper.columns if any(upper[column] > 0.90)]

print("Highly correlated columns:", high_corr)

df = datas.drop(columns=high_corr)
# Out:
# Highly correlated columns: ['Years of Experience', 'Salary']

# %%
import pandas as pd
datas = pd.read_csv("salary data.csv")
print(df.columns)

X = datas.drop("Education Level", axis=1)
y = datas["Education Level"]

print(X.shape, y.shape)
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title'], dtype='object')
# (375, 5) (375,)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid") 


sns.scatterplot(x="Years of Experience", y="Salary", data=datas)
plt.show()                                                   

sns.boxplot(x="Education Level", y="Salary", data=datas)
plt.xticks(rotation=45)
plt.show()

# %%
sns.set_style("whitegrid") 


sns.scatterplot(x="Gender", y="Years of Experience", data=datas)
plt.show()                                                   


sns.boxplot(x="Gender", y="Age", data=datas)
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(datas.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()
